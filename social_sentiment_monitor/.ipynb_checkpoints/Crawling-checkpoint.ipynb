# %% [markdown]
# ## Import Libraries

# %%
import os
import time
import pandas as pd
import requests
from tqdm import tqdm
from urllib.parse import quote_plus

# %% [markdown]
# ## Define Parameters and Keywords

# %%
# Replace with your keys (or load via .env)
CLIENT_ID = "xxx"
CLIENT_SECRET = "xxx"

HEADERS = {
    "X-Naver-Client-Id": CLIENT_ID,
    "X-Naver-Client-Secret": CLIENT_SECRET
}

KEYWORDS = ["경제", "물가", "인플레이션", "금리", "부동산", "경기침체"]
def build_query(base_kw):
    return f"2025년 9월 {base_kw}"
SAVE_PATH = "data/economic_news_api.csv"
os.makedirs("data", exist_ok=True)

# %% [markdown]
# ## Define Fetch Function

# %%
def fetch_news(query, display=100, start=1, sort="date"):
    """Fetch news from Naver OpenAPI"""
    base_url = "https://openapi.naver.com/v1/search/news.json"
    params = {
        "query": query,
        "display": display,
        "start": start,
        "sort": sort
    }
    res = requests.get(base_url, headers=HEADERS, params=params)
    if res.status_code == 200:
        return res.json().get("items", [])
    else:
        print(f"Error {res.status_code}: {res.text}")
        return []

# %% [markdown]
# ## Crawl Multiple Keywords

# %%
all_results = []

for kw in tqdm(KEYWORDS, desc="Keywords (9월)"):
    query = build_query(kw)
    for start in range(1, 1000, 100):  # up to 1000 results per keyword
        items = fetch_news(query, display=100, start=start)
        if not items:
            break
        for it in items:
            all_results.append({
                "keyword": kw,
                "title": it["title"].replace("<b>", "").replace("</b>", ""),
                "summary": it["description"].replace("<b>", "").replace("</b>", ""),
                "link": it["link"],
                "originallink": it.get("originallink", ""),
                "pubDate": it["pubDate"]
            })
        time.sleep(0.5)
# Out:
# Keywords (9월): 100%|████████████████████████████████████████████████████████████████████| 6/6 [00:39<00:00,  6.62s/it]

# %% [markdown]
# ## Save Results

# %%
df = pd.DataFrame(all_results)
df.drop_duplicates(subset=["link"], inplace=True)
df["pubDate"] = pd.to_datetime(df["pubDate"])
df.to_csv("data/economic_news_sep2025.csv", index=False, encoding="utf-8-sig")

print(f"Saved {len(df)} rows (September-focused data)")
df.head()
# Out:
# Saved 4630 rows (September-focused data)
#   keyword                                    title  \
# 0      경제        여야, 추석 민심 '아전인수' 해석…밑바닥은 '경제 어렵다'
# 1      경제        자영업자 산재 의무가입 시대 열리나...정부, 의무가입 추진
# 2      경제           성남시, 노무제공자 예술인 산재보험료 지원 하반기 접수
# 3      경제  [기획] 의정부시, '실내·실외 놀이 공간 활용' 아동의 놀 권리 보장
# 4      경제           성남시, 노무제공자·예술인 산재보험료 지원 하반기 접수
#
#                                              summary  \
# 0  [사진=전남도] 2025.10.03 ej7648@newspim.com 민심은 경제가...
# 1  고용노동부 산하 산업안전보건본부가 발표한 '2025년 2분기 산업재해 현황'에 따르...
# 2  노동취약계층의 경제적 부담을 줄이기 위해 보험료를 자체 지원하고 있다. 지원... ...
# 3  com ◆ 도시공원 놀이터, 안전과 접근성 높이다 2025년 10월 기준 의정부시 ...
# 4  성남시는 업무상 재해 보상을 위한 산재보험 가입이 의무화된 상황에서 이들 노동취약계...
#
#                                                 link  \
# 0   https://www.newspim.com/news/view/20251010000822
# 1  https://www.financialpost.co.kr/news/articleVi...
# 2                   http://www.breaknews.com/1152976
# 3   https://www.newspim.com/news/view/20251010000749
# 4  https://n.news.naver.com/mnews/article/047/000...
#
#                                         originallink                   pubDate
# 0   https://www.newspim.com/news/view/20251010000822 2025-10-10 17:16:00+09:00
# 1  https://www.financialpost.co.kr/news/articleVi... 2025-10-10 17:12:00+09:00
# 2                   http://www.breaknews.com/1152976 2025-10-10 17:10:00+09:00
# 3   https://www.newspim.com/news/view/20251010000749 2025-10-10 17:04:00+09:00
# 4  https://www.ohmynews.com/NWS_Web/View/at_pg.as... 2025-10-10 17:04:00+09:00
